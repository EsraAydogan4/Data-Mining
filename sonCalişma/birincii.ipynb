# %%
import pandas as pd

# %%
df = pd.read_csv("resources/jamesbond.csv")
df # dosya okuma işlemini yapabilmek için pandas kütüphanesini kullanmak gerekiyor
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
liste = [3, 4, 5]

# %%
liste = pd.Series([3, 5, 6, 6,3, 3])

# %%
liste.sum() #pandas kullanılmadan bu fonksiyonlar kullanılmıyor.
# Out:
# 26

# %%
liste.mode()
# Out:
# 0    3
# dtype: int64

# %%
liste.values
# Out:
# array([3, 5, 6, 6, 3, 3], dtype=int64)

# %%
type(liste.values)
# Out:
# numpy.ndarray

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               26 non-null     object
#  1   Year               26 non-null     int64
#  2   Actor              26 non-null     object
#  3   Director           26 non-null     object
#  4   Box Office         26 non-null     float64
#  5   Budget             26 non-null     float64
#  6   Bond Actor Salary  18 non-null     float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.6+ KB

# %%
df.head(10) # ilk 10 indexteki değerleri getirir.
# Out:
#                               Film  Year           Actor       Director  \
# 0                           Dr. No  1962    Sean Connery  Terence Young
# 1            From Russia with Love  1963    Sean Connery  Terence Young
# 2                       Goldfinger  1964    Sean Connery   Guy Hamilton
# 3                      Thunderball  1965    Sean Connery  Terence Young
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# 7             Diamonds Are Forever  1971    Sean Connery   Guy Hamilton
# 8                 Live and Let Die  1973     Roger Moore   Guy Hamilton
# 9      The Man with the Golden Gun  1974     Roger Moore   Guy Hamilton
#
#    Box Office  Budget  Bond Actor Salary
# 0       448.8     7.0                0.6
# 1       543.8    12.6                1.6
# 2       820.4    18.6                3.2
# ...

# %%
df.tail(1) # istenilen kadar son değerleri getirir.
# Out:
#        Film  Year         Actor    Director  Box Office  Budget  \
# 25  Spectre  2015  Daniel Craig  Sam Mendes       726.7   206.3
#
#     Bond Actor Salary
# 25                NaN

# %%
df.isna() # Nan olan değerler true olarak görünüyor
# Out:
#      Film   Year  Actor  Director  Box Office  Budget  Bond Actor Salary
# 0   False  False  False     False       False   False              False
# 1   False  False  False     False       False   False              False
# 2   False  False  False     False       False   False              False
# 3   False  False  False     False       False   False              False
# 4   False  False  False     False       False   False               True
# 5   False  False  False     False       False   False              False
# 6   False  False  False     False       False   False              False
# 7   False  False  False     False       False   False              False
# 8   False  False  False     False       False   False               True
# 9   False  False  False     False       False   False               True
# 10  False  False  False     False       False   False               True
# 11  False  False  False     False       False   False               True
# ...

# %%
df.isna().sum() # hangi sutunda kaç tane Nan değer olduğunu döndürdü.
# Out:
# Film                 0
# Year                 0
# Actor                0
# Director             0
# Box Office           0
# Budget               0
# Bond Actor Salary    8
# dtype: int64

# %%
df.describe().T  # sayısal verilerin olduğu sutünların olasılıkları ge
# Out:
#                    count         mean         std     min       25%      50%  \
# Year                26.0  1983.576923   16.295209  1962.0  1969.500  1982.00
# Box Office          26.0   491.611538  176.740396   250.9   375.350   461.75
# Budget              26.0    80.719231   57.097608     7.0    38.450    60.05
# Bond Actor Salary   18.0     6.850000    4.805175     0.6     3.575     5.50
#
#                        75%     max
# Year               1996.50  2015.0
# Box Office          534.50   943.5
# Budget              123.30   206.3
# Bond Actor Salary     8.85    17.9

# %%
df.squeeze("columns")
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
len(df)
# Out:
# 26

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
dir(df) # df nin sahip olduğu attribute ve methotları getirir
# Out:
# ['Actor',
#  'Budget',
#  'Director',
#  'Film',
#  'T',
#  'Year',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
# ...

# %%
sorted(df)
# Out:
# ['Actor',
#  'Bond Actor Salary',
#  'Box Office',
#  'Budget',
#  'Director',
#  'Film',
#  'Year']

# %%
sorted(df, reverse=True)
# Out:
# ['Year',
#  'Film',
#  'Director',
#  'Budget',
#  'Box Office',
#  'Bond Actor Salary',
#  'Actor']

# %%
dict(df) # seriyi dicte çevirir
# Out:
# {'Film': 0                              Dr. No
#  1               From Russia with Love
#  2                          Goldfinger
#  3                         Thunderball
#  4                       Casino Royale
#  5                 You Only Live Twice
#  6     On Her Majesty's Secret Service
#  7                Diamonds Are Forever
#  8                    Live and Let Die
#  9         The Man with the Golden Gun
#  10               The Spy Who Loved Me
#  11                          Moonraker
#  12                 For Your Eyes Only
#  13              Never Say Never Again
#  14                          Octopussy
#  15                   A View to a Kill
#  16               The Living Daylights
#  17                    Licence to Kill
#  18                          GoldenEye
#  19                Tomorrow Never Dies
#  20            The World Is Not Enough
#  21                    Die Another Day
#  22                      Casino Royale
#  23                  Quantum of Solace
# ...

# %%
max(df) # sondaki veriyi verir min ilkteki veriyi getirir
# Out:
# 'Year'

# %%
df.sort_values(by="Film")
# Out:
#                                Film  Year           Actor            Director  \
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# ...

# %%
df.sort_index(ascending=False) # indexe göre sıralama yapılır. ascending=True verilirse k=>b sıralar
# Out:
#                                Film  Year           Actor            Director  \
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# ...

# %%
df
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
"Skyfall" in df.values # verilen değerin df olup olmadığına bakar
# Out:
# True

# %%
df.values[3]
# Out:
# array(['Thunderball', 1965, 'Sean Connery', 'Terence Young', 848.1, 41.9,
#        4.7], dtype=object)

# %%
df.values[3, 1] # 3. satırın 1. sütununu getirir.
# Out:
# 1965

# %%
df.values[3][2] # 3. satırın 2. sütununu getirir.
# Out:
# array(['Sean Connery'], dtype=object)

# %%
df.values[0:10:2]
# Out:
# array([['Dr. No', 1962, 'Sean Connery', 'Terence Young', 448.8, 7.0, 0.6],
#        ['Goldfinger', 1964, 'Sean Connery', 'Guy Hamilton', 820.4, 18.6,
#         3.2],
#        ['Casino Royale', 1967, 'David Niven', 'Ken Hughes', 315.0, 85.0,
#         nan],
#        ["On Her Majesty's Secret Service", 1969, 'George Lazenby',
#         'Peter R. Hunt', 291.5, 37.3, 0.6],
#        ['Live and Let Die', 1973, 'Roger Moore', 'Guy Hamilton', 460.3,
#         30.8, nan]], dtype=object)

# %%
df.get(1)

# %%
df.Film
# Out:
# 0                              Dr. No
# 1               From Russia with Love
# 2                          Goldfinger
# 3                         Thunderball
# 4                       Casino Royale
# 5                 You Only Live Twice
# 6     On Her Majesty's Secret Service
# 7                Diamonds Are Forever
# 8                    Live and Let Die
# 9         The Man with the Golden Gun
# 10               The Spy Who Loved Me
# 11                          Moonraker
# 12                 For Your Eyes Only
# 13              Never Say Never Again
# 14                          Octopussy
# 15                   A View to a Kill
# 16               The Living Daylights
# 17                    Licence to Kill
# 18                          GoldenEye
# 19                Tomorrow Never Dies
# 20            The World Is Not Enough
# 21                    Die Another Day
# 22                      Casino Royale
# 23                  Quantum of Solace
# 24                            Skyfall
# ...

# %%
df["Film"]
# Out:
# 0                              Dr. No
# 1               From Russia with Love
# 2                          Goldfinger
# 3                         Thunderball
# 4                       Casino Royale
# 5                 You Only Live Twice
# 6     On Her Majesty's Secret Service
# 7                Diamonds Are Forever
# 8                    Live and Let Die
# 9         The Man with the Golden Gun
# 10               The Spy Who Loved Me
# 11                          Moonraker
# 12                 For Your Eyes Only
# 13              Never Say Never Again
# 14                          Octopussy
# 15                   A View to a Kill
# 16               The Living Daylights
# 17                    Licence to Kill
# 18                          GoldenEye
# 19                Tomorrow Never Dies
# 20            The World Is Not Enough
# 21                    Die Another Day
# 22                      Casino Royale
# 23                  Quantum of Solace
# 24                            Skyfall
# ...

# %%
df[df["Director"] == "Terence Young"]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 3    41.9                4.7

# %%
df[df["Director"] != "Terence Young"]
# Out:
#                                Film  Year           Actor            Director  \
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# ...

# %%
import numpy as np
def get_outliers(incoming_df):
 result = {}
 num_df = incoming_df.select_dtypes(include=np.number)
 for col in num_df.columns:
     q3, q1 = np.percentile(incoming_df[col], [75 ,25])
     iqr = q3 - q1
     outliers = df[col][(df[col] < q1 - 1.5 * iqr) | (df[col] > q3 + 1.5 * iqr)].tolist()
     result[col] = outliers
 return result
