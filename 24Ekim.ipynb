# %%
import pandas as pd

# %%
example = {
    "Kitap" : 15,
    "Defter" :20,
    "Kalem" :30
}
example
# Out:
# {'Kitap': 15, 'Defter': 20, 'Kalem': 30}

# %%
pd.Series(example)
# Out:
# Kitap     15
# Defter    20
# Kalem     30
# dtype: int64

# %%
deneme = pd.Series([1, 2, 3, "soru"])
deneme
# Out:
# 0       1
# 1       2
# 2       3
# 3    soru
# dtype: object

# %%
try:
    deneme.sum()
except:
    print("hata")
# Out:
# hata

# %%
len(deneme)
# Out:
# 4

# %%
deneme
# Out:
# 0       1
# 1       2
# 2       3
# 3    soru
# dtype: object

# %%
deneme.is_unique # nesnenin içinde birden fazla tekrar eden eleman varsa false yoksa true döner.
# Out:
# True

# %%
deneme.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df = pd.read_csv("resources/pokemon.csv")
df # yerini gösterdik ve okumasını istedik
# Out:
#         Pokemon     Type
# 0     Bulbasaur    Grass
# 1       Ivysaur    Grass
# 2      Venusaur    Grass
# 3    Charmander     Fire
# 4    Charmeleon     Fire
# ..          ...      ...
# 716     Yveltal     Dark
# 717     Zygarde   Dragon
# 718     Diancie     Rock
# 719       Hoopa  Psychic
# 720   Volcanion     Fire
#
# [721 rows x 2 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv("resources/pokemon.csv", usecols=["Type"])
df
# Out:
#         Type
# 0      Grass
# 1      Grass
# 2      Grass
# 3       Fire
# 4       Fire
# ..       ...
# 716     Dark
# 717   Dragon
# 718     Rock
# 719  Psychic
# 720     Fire
#
# [721 rows x 1 columns]

# %%
srs = pd.read_csv("resources/pokemon.csv", usecols=["Pokemon"]).squeeze("columns")
srs
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
type(srs)
# Out:
# pandas.core.series.Series

# %%
srs.head(n=10) #ilk 10 nesne gelir
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# 5     Charizard
# 6      Squirtle
# 7     Wartortle
# 8     Blastoise
# 9      Caterpie
# Name: Pokemon, dtype: object

# %%
dir(srs)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
sorted(srs, reverse=True)
# Out:
# ['Zygarde',
#  'Zweilous',
#  'Zubat',
#  'Zorua',
#  'Zoroark',
#  'Zigzagoon',
#  'Zekrom',
#  'Zebstrika',
#  'Zapdos',
#  'Zangoose',
#  'Yveltal',
#  'Yanmega',
#  'Yanma',
#  'Yamask',
#  'Xerneas',
#  'Xatu',
#  'Wynaut',
#  'Wurmple',
#  'Wormadam',
#  'Wooper',
#  'Woobat',
#  'Wobbuffet',
#  'Wingull',
#  'Wigglytuff',
#  'Whismur',
#  'Whiscash',
#  'Whirlipede',
#  'Whimsicott',
#  'Weezing',
#  'Weepinbell',
#  'Weedle',
#  'Weavile',
#  'Watchog',
#  'Wartortle',
#  'Walrein',
#  'Wailord',
#  'Wailmer',
#  'Vulpix',
#  'Vullaby',
#  'Voltorb',
#  'Volcarona',
#  'Volcanion',
#  'Volbeat',
#  'Vivillon',
#  'Virizion',
#  'Vileplume',
#  'Vigoroth',
#  'Victreebel',
#  'Victini',
#  'Vibrava',
#  'Vespiquen',
#  'Venusaur',
#  'Venonat',
#  'Venomoth',
#  'Venipede',
#  'Vaporeon',
#  'Vanilluxe',
#  'Vanillite',
#  'Vanillish',
#  'Uxie',
#  'Ursaring',
#  'Unown',
#  'Unfezant',
#  'Umbreon',
#  'Tyrunt',
#  'Tyrogue',
#  'Tyrantrum',
#  'Tyranitar',
#  'Typhlosion',
# ...

# %%
list(srs)
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoran',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidoran♂',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Vulpix',
#  'Ninetales',
#  'Jigglypuff',
#  'Wigglytuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Venomoth',
#  'Diglett',
#  'Dugtrio',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Mankey',
#  'Primeape',
#  'Growlithe',
#  'Arcanine',
#  'Poliwag',
#  'Poliwhirl',
#  'Poliwrath',
#  'Abra',
#  'Kadabra',
#  'Alakazam',
#  'Machop',
#  'Machoke',
#  'Machamp',
# ...

# %%
srs.sort_values(ascending=False).head()
# Out:
# 717     Zygarde
# 633    Zweilous
# 40        Zubat
# 569       Zorua
# 570     Zoroark
# Name: Pokemon, dtype: object

# %%
srs2 = pd.read_csv("resources/pokemon.csv", 
            index_col="Pokemon").squeeze("columns")

# %%
srs2.sort_index(inplace=True)

# %%
"Abra" in srs2
# Out:
# True

# %%
srs2.index
# Out:
# Index(['Abomasnow', 'Abra', 'Absol', 'Accelgor', 'Aegislash', 'Aerodactyl',
#        'Aggron', 'Aipom', 'Alakazam', 'Alomomola',
#        ...
#        'Zangoose', 'Zapdos', 'Zebstrika', 'Zekrom', 'Zigzagoon', 'Zoroark',
#        'Zorua', 'Zubat', 'Zweilous', 'Zygarde'],
#       dtype='object', name='Pokemon', length=721)
