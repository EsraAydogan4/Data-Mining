# %%
import pandas as pd

# %%
fruits = ["Elma", "Armut", "Kiraz"]
fruits
# Out:
# ['Elma', 'Armut', 'Kiraz']

# %%
pd.Series(fruits)
# Out:
# 0     Elma
# 1    Armut
# 2    Kiraz
# dtype: object

# %%
example = {
    "Kitap" : 15,
    "Defter" :20,
    "Kalem" :30
}
example
# Out:
# {'Kitap': 15, 'Defter': 20, 'Kalem': 30}

# %%
pd.Series(example)
# Out:
# Kitap     15
# Defter    20
# Kalem     30
# dtype: int64

# %%
fiyatlar = pd.Series([3, 2, 1, 1.5])
fiyatlar
# Out:
# 0    3.0
# 1    2.0
# 2    1.0
# 3    1.5
# dtype: float64

# %%
fiyatlar.sum() #toplam
# Out:
# 7.5

# %%
fiyatlar.mean() #ortalama
# Out:
# 1.875

# %%
fiyatlar.product() #tüm sayıların çarpımı
# Out:
# 9.0

# %%
fiyatlar.std() # standart sapma
fiyatlar.min() # minimum değer
fiyatlar.max() # max değer
fiyatlar.median() # medyan
fiyatlar.mode() # mod
# Out:
# 0    1.0
# 1    1.5
# 2    2.0
# 3    3.0
# dtype: float64

# %%
deneme = pd.Series([1, 2, 3, "Soru"]) # series listeleme yapıyor 
deneme
# Out:
# 0       1
# 1       2
# 2       3
# 3    Soru
# dtype: object

# %%
try:
    deneme.sum() # hata yakalama için kulanılır 
except:
    print("Hata") # hata diye dönüt yazdırır
# Out:
# Hata

# %%
len(deneme)
# Out:
# 4

# %%
deneme.size
# Out:
# 4

# %%
deneme
# Out:
# 0       1
# 1       2
# 2       3
# 3    Soru
# dtype: object

# %%
deneme.is_unique
# Out:
# True

# %%
deneme.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
deneme.values
# Out:
# array([1, 2, 3, 'Soru', 1], dtype=object)

# %%
meyveler = ["Elma", "Armut", "Kiraz"]
gunler = ["Pazartesi", "Salı", "Çarşamba"]

# %%
pd.Series(meyveler, gunler) # ilk verilen nesne data 2. index olur
# Out:
# Pazartesi     Elma
# Salı         Armut
# Çarşamba     Kiraz
# dtype: object

# %%
pd.Series(index=meyveler, data=gunler)
# Out:
# Elma     Pazartesi
# Armut         Salı
# Kiraz     Çarşamba
# dtype: object

# %%
df = pd.read_csv("resources/pokemon.csv")
df
# Out:
#         Pokemon     Type
# 0     Bulbasaur    Grass
# 1       Ivysaur    Grass
# 2      Venusaur    Grass
# 3    Charmander     Fire
# 4    Charmeleon     Fire
# ..          ...      ...
# 716     Yveltal     Dark
# 717     Zygarde   Dragon
# 718     Diancie     Rock
# 719       Hoopa  Psychic
# 720   Volcanion     Fire
#
# [721 rows x 2 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv("resources/pokemon.csv", usecols=["Pokemon"])
df
# Out:
#         Pokemon
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# ..          ...
# 716     Yveltal
# 717     Zygarde
# 718     Diancie
# 719       Hoopa
# 720   Volcanion
#
# [721 rows x 1 columns]

# %%
srs = pd.read_csv("resources/pokemon.csv", 
                  usecols=["Pokemon"]).squeeze("columns")
srs
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
type(srs)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### srs.head(n=10)

# %%
srs.tail(n=8)
# Out:
# 713       Noibat
# 714      Noivern
# 715      Xerneas
# 716      Yveltal
# 717      Zygarde
# 718      Diancie
# 719        Hoopa
# 720    Volcanion
# Name: Pokemon, dtype: object

# %%
sorted(srs, reverse=True)
# Out:
# ['Zygarde',
#  'Zweilous',
#  'Zubat',
#  'Zorua',
#  'Zoroark',
#  'Zigzagoon',
#  'Zekrom',
#  'Zebstrika',
#  'Zapdos',
#  'Zangoose',
#  'Yveltal',
#  'Yanmega',
#  'Yanma',
#  'Yamask',
#  'Xerneas',
#  'Xatu',
#  'Wynaut',
#  'Wurmple',
#  'Wormadam',
#  'Wooper',
#  'Woobat',
#  'Wobbuffet',
#  'Wingull',
#  'Wigglytuff',
#  'Whismur',
#  'Whiscash',
#  'Whirlipede',
#  'Whimsicott',
#  'Weezing',
#  'Weepinbell',
#  'Weedle',
#  'Weavile',
#  'Watchog',
#  'Wartortle',
#  'Walrein',
#  'Wailord',
#  'Wailmer',
#  'Vulpix',
#  'Vullaby',
#  'Voltorb',
#  'Volcarona',
#  'Volcanion',
#  'Volbeat',
#  'Vivillon',
#  'Virizion',
#  'Vileplume',
#  'Vigoroth',
#  'Victreebel',
#  'Victini',
#  'Vibrava',
#  'Vespiquen',
#  'Venusaur',
#  'Venonat',
#  'Venomoth',
#  'Venipede',
#  'Vaporeon',
#  'Vanilluxe',
#  'Vanillite',
#  'Vanillish',
#  'Uxie',
#  'Ursaring',
#  'Unown',
#  'Unfezant',
#  'Umbreon',
#  'Tyrunt',
#  'Tyrogue',
#  'Tyrantrum',
#  'Tyranitar',
#  'Typhlosion',
# ...

# %%
list(srs)
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoran',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidoran♂',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Vulpix',
#  'Ninetales',
#  'Jigglypuff',
#  'Wigglytuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Venomoth',
#  'Diglett',
#  'Dugtrio',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Mankey',
#  'Primeape',
#  'Growlithe',
#  'Arcanine',
#  'Poliwag',
#  'Poliwhirl',
#  'Poliwrath',
#  'Abra',
#  'Kadabra',
#  'Alakazam',
#  'Machop',
#  'Machoke',
#  'Machamp',
# ...

# %%
dict(srs)
# Out:
# {0: 'Bulbasaur',
#  1: 'Ivysaur',
#  2: 'Venusaur',
#  3: 'Charmander',
#  4: 'Charmeleon',
#  5: 'Charizard',
#  6: 'Squirtle',
#  7: 'Wartortle',
#  8: 'Blastoise',
#  9: 'Caterpie',
#  10: 'Metapod',
#  11: 'Butterfree',
#  12: 'Weedle',
#  13: 'Kakuna',
#  14: 'Beedrill',
#  15: 'Pidgey',
#  16: 'Pidgeotto',
#  17: 'Pidgeot',
#  18: 'Rattata',
#  19: 'Raticate',
#  20: 'Spearow',
#  21: 'Fearow',
#  22: 'Ekans',
#  23: 'Arbok',
#  24: 'Pikachu',
#  25: 'Raichu',
#  26: 'Sandshrew',
#  27: 'Sandslash',
#  28: 'Nidoran',
#  29: 'Nidorina',
#  30: 'Nidoqueen',
#  31: 'Nidoran♂',
#  32: 'Nidorino',
#  33: 'Nidoking',
#  34: 'Clefairy',
#  35: 'Clefable',
#  36: 'Vulpix',
#  37: 'Ninetales',
#  38: 'Jigglypuff',
#  39: 'Wigglytuff',
#  40: 'Zubat',
#  41: 'Golbat',
#  42: 'Oddish',
#  43: 'Gloom',
#  44: 'Vileplume',
#  45: 'Paras',
#  46: 'Parasect',
#  47: 'Venonat',
#  48: 'Venomoth',
#  49: 'Diglett',
#  50: 'Dugtrio',
#  51: 'Meowth',
#  52: 'Persian',
#  53: 'Psyduck',
# ...

# %%
srs.sort_values(ascending=False).head()
# Out:
# 717     Zygarde
# 633    Zweilous
# 40        Zubat
# 569       Zorua
# 570     Zoroark
# Name: Pokemon, dtype: object

# %%
srs2 = pd.read_csv("resources/pokemon.csv", 
            index_col="Pokemon").squeeze("columns")

# %%
srs2.sort_index(inplace=True)

# %%
srs2
# Out:
# Pokemon
# Abomasnow      Grass
# Abra         Psychic
# Absol           Dark
# Accelgor         Bug
# Aegislash      Steel
#               ...
# Zoroark         Dark
# Zorua           Dark
# Zubat         Poison
# Zweilous        Dark
# Zygarde       Dragon
# Name: Type, Length: 721, dtype: object

# %%
"Abra" in srs2
# Out:
# True

# %%
"Grass" in srs2.values
# Out:
# True

# %%
srs2.index
# Out:
# Index(['Abomasnow', 'Abra', 'Absol', 'Accelgor', 'Aegislash', 'Aerodactyl',
#        'Aggron', 'Aipom', 'Alakazam', 'Alomomola',
#        ...
#        'Zangoose', 'Zapdos', 'Zebstrika', 'Zekrom', 'Zigzagoon', 'Zoroark',
#        'Zorua', 'Zubat', 'Zweilous', 'Zygarde'],
#       dtype='object', name='Pokemon', length=721)

# %%
type(srs2.index)
# Out:
# pandas.core.indexes.base.Index

# %%
srs2['Abomasnow']
# Out:
# 'Grass'

# %%
srs[0]
# Out:
# 'Bulbasaur'

# %%
srs[[0, 10, 20]]
# Out:
# 0     Bulbasaur
# 10      Metapod
# 20      Spearow
# Name: Pokemon, dtype: object

# %%
srs[0:8]
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# 5     Charizard
# 6      Squirtle
# 7     Wartortle
# Name: Pokemon, dtype: object

# %%
srs[0:8:2]
# Out:
# 0     Bulbasaur
# 2      Venusaur
# 4    Charmeleon
# 6      Squirtle
# Name: Pokemon, dtype: object

# %%
srs[:3]
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# 2     Venusaur
# Name: Pokemon, dtype: object

# %%
srs[715:]
# Out:
# 715      Xerneas
# 716      Yveltal
# 717      Zygarde
# 718      Diancie
# 719        Hoopa
# 720    Volcanion
# Name: Pokemon, dtype: object

# %%
srs[-20:]
# Out:
# 701      Dedenne
# 702      Carbink
# 703        Goomy
# 704      Sliggoo
# 705       Goodra
# 706       Klefki
# 707     Phantump
# 708    Trevenant
# 709    Pumpkaboo
# 710    Gourgeist
# 711     Bergmite
# 712      Avalugg
# 713       Noibat
# 714      Noivern
# 715      Xerneas
# 716      Yveltal
# 717      Zygarde
# 718      Diancie
# 719        Hoopa
# 720    Volcanion
# Name: Pokemon, dtype: object

# %%
srs2[0:10]
# Out:
# Pokemon
# Abomasnow       Grass
# Abra          Psychic
# Absol            Dark
# Accelgor          Bug
# Aegislash       Steel
# Aerodactyl       Rock
# Aggron          Steel
# Aipom          Normal
# Alakazam      Psychic
# Alomomola       Water
# Name: Type, dtype: object

# %%
srs2[["Xerneas", "Diancie"]]
# Out:
# Pokemon
# Xerneas    Fairy
# Diancie     Rock
# Name: Type, dtype: object

# %%
srs2.get("Xerneas")
# Out:
# 'Fairy'

# %%
srs2.get("Xerneas1", "Mevcut Değil")
# Out:
# 'Mevcut Değil'

# %%
srs
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
srs[0] = "Bu ne biçim ders"
srs
# Out:
# 0      Bu ne biçim ders
# 1               Ivysaur
# 2              Venusaur
# 3            Charmander
# 4            Charmeleon
#              ...
# 716             Yveltal
# 717             Zygarde
# 718             Diancie
# 719               Hoopa
# 720           Volcanion
# Name: Pokemon, Length: 721, dtype: object

# %%
srs2[[1, 3, 5]] = ["A", "L", "İ"]
srs2.head(6)
# Out:
# /tmp/ipykernel_3431/4009730054.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   srs2[[1, 3, 5]] = ["A", "L", "İ"]
# Pokemon
# Abomasnow     Grass
# Abra              A
# Absol          Dark
# Accelgor          L
# Aegislash     Steel
# Aerodactyl        İ
# Name: Type, dtype: object

# %%
srs3 = srs2.copy()

# %%
srs3
# Out:
# Pokemon
# Abomasnow     Grass
# Abra              A
# Absol          Dark
# Accelgor          L
# Aegislash     Steel
#               ...
# Zoroark        Dark
# Zorua          Dark
# Zubat        Poison
# Zweilous       Dark
# Zygarde      Dragon
# Name: Type, Length: 721, dtype: object

# %%
srs3[0] = "new"
srs3.head()
# Out:
# Pokemon
# Abomasnow        new
# Abra         Psychic
# Absol           Dark
# Accelgor         Bug
# Aegislash      Steel
# Name: Type, dtype: object

# %%
srs2.head()
# Out:
# Pokemon
# Abomasnow      Grass
# Abra         Psychic
# Absol           Dark
# Accelgor         Bug
# Aegislash      Steel
# Name: Type, dtype: object

# %%
liste = [1, 2, 3, None, 4]

seri = pd.Series(liste)
seri
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# dtype: float64

# %%
seri.size
# Out:
# 5

# %%
len(seri)
# Out:
# 5

# %%
seri.count()
# Out:
# 4

# %%
nba = pd.read_csv("resources/nba.csv")
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
revenue = pd.read_csv("resources/revenue.csv", index_col="Date")
revenue
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
revenue.sum()
revenue.sum(axis=0)
revenue.sum(axis="index")
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
revenue.sum(axis=1)
revenue.sum(axis="columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
nba.Number
# Out:
# 0       0.0
# 1      99.0
# 2      30.0
# 3      28.0
# 4       8.0
#        ...
# 453     8.0
# 454    25.0
# 455    21.0
# 456    24.0
# 457     NaN
# Name: Number, Length: 458, dtype: float64

# %%
nba["Name"]
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
nba[["Name", "Position", "Salary"]]
# Out:
#               Name Position     Salary
# 0    Avery Bradley       PG  7730337.0
# 1      Jae Crowder       SF  6796117.0
# 2     John Holland       SG        NaN
# 3      R.J. Hunter       SG  1148640.0
# 4    Jonas Jerebko       PF  5000000.0
# ..             ...      ...        ...
# 453   Shelvin Mack       PG  2433333.0
# 454      Raul Neto       PG   900000.0
# 455   Tibor Pleiss        C  2900000.0
# 456    Jeff Withey        C   947276.0
# 457            NaN      NaN        NaN
#
# [458 rows x 3 columns]

# %%
nba["College"] = "SDÜ"
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#     College     Salary
# 0       SDÜ  7730337.0
# 1       SDÜ  6796117.0
# ...

# %%
nba.to_csv("resources/nba_new.csv")
